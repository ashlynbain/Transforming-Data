# %% [markdown]
# # Transforming Data

# %% [markdown]
# ## Reading the data (sample)

# %%
#Reading the Data
#Creating Data Frame

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from io import StringIO
import re

predf = open('1689.csv').read()

# %%
predf
# Out:
# '\ufeffThis document was exported from the paperMoney® platform which provides a simulated trading environment. All data contained herein is for educational and entertainment purposes only. TD Ameritrade its subsidiaries and/or affiliates are not responsible for the accuracy of any of these exported data.\n\nthinkBack: Stock quote and option quote for SPY on 8/27/20 23:59:59\n\nUNDERLYING\nLast,Net Chng,Volume,Open,High,Low\n348.33,+.76,"58,034,142",348.51,349.90,346.53\n\n28 AUG 20  (1)  100 (Weeklys)\n,,Volume,Open.Int,Bid,Ask,Exp,Strike,Bid,Ask,Volume,Open.Int,,\n,,"37,715","17,786",2.34,2.39,28 AUG 20,347,.77,.79,"139,681","12,664",,\n,,"103,279","18,422",1.65,1.68,28 AUG 20,348,1.07,1.10,"127,223","5,648",,\n,,"164,013","19,097",1.10,1.11,28 AUG 20,349,1.50,1.54,"93,045","1,367",,\n,,"208,464","20,152",.67,.69,28 AUG 20,350,2.07,2.11,"40,913","1,284",,\n\n31 AUG 20  (4)  100 (Weeklys)\n,,Volume,Open.Int,Bid,Ask,Exp,Strike,Bid,Ask,Volume,Open.Int,,\n,,"6,421","5,271",3.00,3.05,31
# ...

# %% [markdown]
# ## Splittng the data

# %%
predf = predf.split('\n\n')
df2 = predf[2:3]
predf = predf[3:]
fef = [] 
for i in range(len(predf)):
    predf[i] = predf[i].split('\n')[2:]
    fef += predf[i]

# %%
df_ = StringIO('\n'.join(fef))
df = pd.read_csv(df_, header = None)
df = df.drop(columns=[0,1,12,13])

# %% [markdown]
# ## Final Data

# %%
df.rename(columns ={ 2:'C Volume', 3:'C Open Int', 4:'C Bid',5:'C Ask',6:'Expiration',7:'Strike',8:'P Bid',9:'P Ask',10:'P Volume',11:'P Open Int'})
# Out:
#    C Volume C Open Int  C Bid  C Ask Expiration  Strike  P Bid  P Ask  \
# 0    37,715     17,786   2.34   2.39  28 AUG 20     347   0.77   0.79
# 1   103,279     18,422   1.65   1.68  28 AUG 20     348   1.07   1.10
# 2   164,013     19,097   1.10   1.11  28 AUG 20     349   1.50   1.54
# 3   208,464     20,152   0.67   0.69  28 AUG 20     350   2.07   2.11
# 4     6,421      5,271   3.00   3.05  31 AUG 20     347   1.42   1.45
# 5    25,953      3,398   2.36   2.40  31 AUG 20     348   1.77   1.81
# 6    26,589      2,167   1.80   1.83  31 AUG 20     349   2.21   2.25
# 7    59,678     11,038   1.32   1.35  31 AUG 20     350   2.72   2.78
# 8     3,705      3,561   3.73   3.77   2 SEP 20     347   2.14   2.17
# 9    13,236      2,045   3.10   3.13   2 SEP 20     348   2.51   2.55
# 10    9,163      2,486   2.53   2.57   2 SEP 20     349   2.93   2.99
# 11    8,688      2,414   2.03   2.06   2 SEP 20     350   3.44   3.49
# ...
